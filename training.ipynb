# %% [markdown]
# <a href="https://colab.research.google.com/github/lukeforehand/deertracker/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/lukeforehand/deertracker
% cd /content/deertracker/
! git pull
% pip install --quiet -r requirements.txt


from google.colab import drive
import tarfile
import shutil
import pathlib

drive.mount("/content/drive", force_remount=True)
shutil.rmtree(pathlib.Path("./training_imgs"), ignore_errors=True)

with tarfile.open("../drive/My Drive/whitetail_crops.tar.gz", "r:gz") as tar:
  tar.extractall()

! python -m deertracker.main train --images ./training_imgs/
# Out:
# fatal: destination path 'deertracker' already exists and is not an empty directory.
# /content/deertracker
# Already up to date.
# Mounted at /content/drive
# 2020-12-01 23:56:50.308058: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Found 6560 files belonging to 20 classes.
# Using 5248 files for training.
# 2020-12-01 23:56:52.336061: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-01 23:56:52.396451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-01 23:56:52.397001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# ...
